# %%
from ppo2 import train, CFG
from policy import make_mlp, make_transformer
from turan_env_c import CHECKER_C4

CFG['checker_id'] = CHECKER_C4
CFG['n']          = 20
policy = make_mlp(n=20, device='cuda')
policy, history = train(CFG, policy)
# Out:
# /root/backtoRL/.venv/lib/python3.12/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# PPO  n=20  envs=4096  checker=1  device=cuda
# transitions/update: 262,144   total iters: 76
# params: 385,983
#
# 200 steps x 4096 envs in 0.02s
#   40,418,942 steps/sec
#   40.42M steps/sec
# iter    10 | steps 2.62M | fps 109,654 | ret 18.73 | best 42.96 | pg -0.0119 | vf 7.157 | ent 4.951 | clip 0.158 | t 24s
# iter    20 | steps 5.24M | fps 110,655 | ret 36.14 | best 42.96 | pg -0.0105 | vf 30.677 | ent 3.180 | clip 0.154 | t 47s
# iter    30 | steps 7.86M | fps 125,055 | ret 33.62 | best 42.96 | pg -0.0111 | vf 13.480 | ent 3.203 | clip 0.178 | t 70s
# ...
